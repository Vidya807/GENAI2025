# %%
import pandas as pd
import numpy as np

# %%
### Merge and Append Joins

# %%
import pandas as pd

# First DataFrame: Marks
df1 = pd.DataFrame({
    'Name': ['VIDYA', 'VIDYA', 'RIZU', 'BHAVYA'],
    'Marks': [10, 20, 30, 40]
})

# Second DataFrame: Gender
df2 = pd.DataFrame({
    'Name': ['VIDYA', 'VIDYA', 'VIDYA', 'TIGER', 'RAMU'],
    'Gender': ['Male', 'Female', 'Male', 'Female', 'Male']
})

# %%
df1
# Out:
#      Name  Marks
# 0   VIDYA     10
# 1   VIDYA     20
# 2    RIZU     30
# 3  BHAVYA     40

# %%
df2
# Out:
#     Name  Gender
# 0  VIDYA    Male
# 1  VIDYA  Female
# 2  VIDYA    Male
# 3  TIGER  Female
# 4   RAMU    Male

# %%
pd.merge(df1,df2,on=['Name'],how='inner')
# Out:
#     Name  Marks  Gender
# 0  VIDYA     10    Male
# 1  VIDYA     10  Female
# 2  VIDYA     10    Male
# 3  VIDYA     20    Male
# 4  VIDYA     20  Female
# 5  VIDYA     20    Male

# %%
import pandas as pd

# Sales Transactions Table
df_sales = pd.DataFrame({
    'CustomerID': ['VIDYA', 'VIDYA', 'BHAVYA', 'RIZU'],
    'TransactionAmount': [10, 20, 30, 40],
    'TransactionID': ['T001', 'T002', 'T003', 'T004'],
    'Date': ['2024-06-01', '2024-06-05', '2024-06-07', '2024-06-08']
})

# %%
# Customer Details Table
df_customers = pd.DataFrame({
    'CustomerID': ['VIDYA', 'VIDYA', 'TIGER', 'RIZU', 'RIZU'],
    'Gender': ['Male', 'Female', 'Male', 'Female', 'Male'],
    'Location': ['Mumbai', 'Mumbai', 'Delhi', 'Chennai', 'Hyderabad']
})

# %%
df_sales
# Out:
#   CustomerID  TransactionAmount TransactionID        Date
# 0      VIDYA                 10          T001  2024-06-01
# 1      VIDYA                 20          T002  2024-06-05
# 2     BHAVYA                 30          T003  2024-06-07
# 3       RIZU                 40          T004  2024-06-08

# %%
pd.merge(df_sales,df_customers,on='CustomerID',how='inner')
# Out:
#   CustomerID  TransactionAmount TransactionID        Date  Gender   Location
# 0      VIDYA                 10          T001  2024-06-01    Male     Mumbai
# 1      VIDYA                 10          T001  2024-06-01  Female     Mumbai
# 2      VIDYA                 20          T002  2024-06-05    Male     Mumbai
# 3      VIDYA                 20          T002  2024-06-05  Female     Mumbai
# 4       RIZU                 40          T004  2024-06-08  Female    Chennai
# 5       RIZU                 40          T004  2024-06-08    Male  Hyderabad

# %%
df_customers
# Out:
#   CustomerID  Gender   Location
# 0      VIDYA    Male     Mumbai
# 1      VIDYA  Female     Mumbai
# 2      TIGER    Male      Delhi
# 3       RIZU  Female    Chennai
# 4       RIZU    Male  Hyderabad

# %%
df1
# Out:
#      Name  Marks
# 0   VIDYA     10
# 1   VIDYA     20
# 2    RIZU     30
# 3  BHAVYA     40

# %%
df2
# Out:
#     Name  Gender
# 0  VIDYA    Male
# 1  VIDYA  Female
# 2  VIDYA    Male
# 3  TIGER  Female
# 4   RAMU    Male

# %%
pd.merge(df1,df2,on='Name',how='left')
# Out:
#      Name  Marks  Gender
# 0   VIDYA     10    Male
# 1   VIDYA     10  Female
# 2   VIDYA     10    Male
# 3   VIDYA     20    Male
# 4   VIDYA     20  Female
# 5   VIDYA     20    Male
# 6    RIZU     30     NaN
# 7  BHAVYA     40     NaN

# %%
df1
# Out:
#      Name  Marks
# 0   VIDYA     10
# 1   VIDYA     20
# 2    RIZU     30
# 3  BHAVYA     40

# %%
df2
# Out:
#     Name  Gender
# 0  VIDYA    Male
# 1  VIDYA  Female
# 2  VIDYA    Male
# 3  TIGER  Female
# 4   RAMU    Male

# %%
pd.merge(df2,df1,on='Name',how='left')
# Out:
#     Name  Gender  Marks
# 0  VIDYA    Male   10.0
# 1  VIDYA    Male   20.0
# 2  VIDYA  Female   10.0
# 3  VIDYA  Female   20.0
# 4  VIDYA    Male   10.0
# 5  VIDYA    Male   20.0
# 6  TIGER  Female    NaN
# 7   RAMU    Male    NaN

# %%
df1
# Out:
#      Name  Marks
# 0   VIDYA     10
# 1   VIDYA     20
# 2    RIZU     30
# 3  BHAVYA     40

# %%
df2
# Out:
#     Name  Gender
# 0  VIDYA    Male
# 1  VIDYA  Female
# 2  VIDYA    Male
# 3  TIGER  Female
# 4   RAMU    Male

# %%
pd.merge(df2,df1,on='Name',how='right')
# Out:
#      Name  Gender  Marks
# 0   VIDYA    Male     10
# 1   VIDYA  Female     10
# 2   VIDYA    Male     10
# 3   VIDYA    Male     20
# 4   VIDYA  Female     20
# 5   VIDYA    Male     20
# 6    RIZU     NaN     30
# 7  BHAVYA     NaN     40

# %%
df1
# Out:
#      Name  Marks
# 0   VIDYA     10
# 1   VIDYA     20
# 2    RIZU     30
# 3  BHAVYA     40

# %%
df2
# Out:
#     Name  Gender
# 0  VIDYA    Male
# 1  VIDYA  Female
# 2  VIDYA    Male
# 3  TIGER  Female
# 4   RAMU    Male

# %%
pd.merge(df2,df1,on='Name',how='left',indicator=True)
# Out:
#     Name  Gender  Marks     _merge
# 0  VIDYA    Male   10.0       both
# 1  VIDYA    Male   20.0       both
# 2  VIDYA  Female   10.0       both
# 3  VIDYA  Female   20.0       both
# 4  VIDYA    Male   10.0       both
# 5  VIDYA    Male   20.0       both
# 6  TIGER  Female    NaN  left_only
# 7   RAMU    Male    NaN  left_only

# %%
df1.values
# Out:
# array([['VIDYA', 10],
#        ['VIDYA', 20],
#        ['RIZU', 30],
#        ['BHAVYA', 40]], dtype=object)

# %%
x=[1,2,3]
y=[4,5,6]

# %%
for i in df1.values:
  for j in df2.values:
    print([list(i),list(j)])
# Out:
# [['VIDYA', 10], ['VIDYA', 'Male']]
# [['VIDYA', 10], ['VIDYA', 'Female']]
# [['VIDYA', 10], ['VIDYA', 'Male']]
# [['VIDYA', 10], ['TIGER', 'Female']]
# [['VIDYA', 10], ['RAMU', 'Male']]
# [['VIDYA', 20], ['VIDYA', 'Male']]
# [['VIDYA', 20], ['VIDYA', 'Female']]
# [['VIDYA', 20], ['VIDYA', 'Male']]
# [['VIDYA', 20], ['TIGER', 'Female']]
# [['VIDYA', 20], ['RAMU', 'Male']]
# [['RIZU', 30], ['VIDYA', 'Male']]
# [['RIZU', 30], ['VIDYA', 'Female']]
# [['RIZU', 30], ['VIDYA', 'Male']]
# [['RIZU', 30], ['TIGER', 'Female']]
# [['RIZU', 30], ['RAMU', 'Male']]
# [['BHAVYA', 40], ['VIDYA', 'Male']]
# [['BHAVYA', 40], ['VIDYA', 'Female']]
# [['BHAVYA', 40], ['VIDYA', 'Male']]
# [['BHAVYA', 40], ['TIGER', 'Female']]
# [['BHAVYA', 40], ['RAMU', 'Male']]

# %%
df1['constant']=1
df2['constant']=1

# %%
df1
# Out:
#      Name  Marks  constant
# 0   VIDYA     10         1
# 1   VIDYA     20         1
# 2    RIZU     30         1
# 3  BHAVYA     40         1

# %%
df2
# Out:
#     Name  Gender  constant
# 0  VIDYA    Male         1
# 1  VIDYA  Female         1
# 2  VIDYA    Male         1
# 3  TIGER  Female         1
# 4   RAMU    Male         1

# %%
pd.merge(df1,df2,on='constant',how='inner')
# Out:
#     Name_x  Marks  constant Name_y  Gender
# 0    VIDYA     10         1  VIDYA    Male
# 1    VIDYA     10         1  VIDYA  Female
# 2    VIDYA     10         1  VIDYA    Male
# 3    VIDYA     10         1  TIGER  Female
# 4    VIDYA     10         1   RAMU    Male
# 5    VIDYA     20         1  VIDYA    Male
# 6    VIDYA     20         1  VIDYA  Female
# 7    VIDYA     20         1  VIDYA    Male
# 8    VIDYA     20         1  TIGER  Female
# 9    VIDYA     20         1   RAMU    Male
# 10    RIZU     30         1  VIDYA    Male
# 11    RIZU     30         1  VIDYA  Female
# 12    RIZU     30         1  VIDYA    Male
# 13    RIZU     30         1  TIGER  Female
# 14    RIZU     30         1   RAMU    Male
# 15  BHAVYA     40         1  VIDYA    Male
# 16  BHAVYA     40         1  VIDYA  Female
# 17  BHAVYA     40         1  VIDYA    Male
# 18  BHAVYA     40         1  TIGER  Female
# 19  BHAVYA     40         1   RAMU    Male
